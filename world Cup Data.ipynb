# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/DELL/Dropbox\PC/Downloads/world_cup.csv")

# %%
data
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
data.head()
# Out:
#    Year          Host  Teams Champion    Runner-Up  \
# 0  2022         Qatar     32      NaN          NaN
# 1  2018        Russia     32   France      Croatia
# 2  2014        Brazil     32  Germany    Argentina
# 3  2010  South Africa     32    Spain  Netherlands
# 4  2006       Germany     32    Italy       France
#
#                               TopScorrer  Attendance  AttendanceAvg  Matches
# 0                                    NaN           0              0        0
# 1                         Harry Kane - 6     3031768          47371       64
# 2                    James Rodríguez - 6     3429873          53592       64
# 3  Wesley Sneijder, Thomas Müller... - 5     3178856          49670       64
# 4                     Miroslav Klose - 5     3352605          52384       64

# %%
data.tail()
# Out:
#     Year         Host  Teams Champion       Runner-Up             TopScorrer  \
# 17  1954  Switzerland     16  Germany         Hungary     Sándor Kocsis - 11
# 18  1950       Brazil     15  Uruguay   United States             Ademir - 8
# 19  1938       France     16    Italy         Hungary           Leônidas - 7
# 20  1934        Italy     16    Italy  Czechoslovakia    Oldřich Nejedlý - 5
# 21  1930      Uruguay     13  Uruguay       Argentina  Guillermo Stábile - 8
#
#     Attendance  AttendanceAvg  Matches
# 17      768607          29562       26
# 18     1045246          47511       22
# 19      375700          20872       18
# 20      363000          21353       17
# 21      590549          32808       18

# %%
data.info
# Out:
# <bound method DataFrame.info of     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# ...

# %%
data.shape
# Out:
# (22, 9)

# %%
data.columns
# Out:
# Index(['Year', 'Host', 'Teams', 'Champion', 'Runner-Up', 'TopScorrer',
#        'Attendance', 'AttendanceAvg', 'Matches'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Year      Teams    Attendance  AttendanceAvg    Matches
# count    22.000000  22.000000  2.200000e+01      22.000000  22.000000
# mean   1978.909091  22.363636  1.847462e+06   40310.772727  40.909091
# std      27.738419   7.454915  1.134035e+06   14930.105032  19.341318
# min    1930.000000  13.000000  0.000000e+00       0.000000   0.000000
# 25%    1959.000000  16.000000  8.381505e+05   30373.500000  27.500000
# 50%    1980.000000  20.000000  1.734864e+06   45703.000000  38.000000
# 75%    2001.000000  32.000000  2.853942e+06   49036.250000  61.000000
# max    2022.000000  32.000000  3.587538e+06   68991.000000  64.000000

# %%
data.isnull().sum()
# Out:
# Year             0
# Host             0
# Teams            0
# Champion         1
# Runner-Up        1
# TopScorrer       1
# Attendance       0
# AttendanceAvg    0
# Matches          0
# dtype: int64

# %%
#visualization
#finding relationship between dataset
data.head()
# Out:
#    Year          Host  Teams Champion    Runner-Up  \
# 0  2022         Qatar     32      NaN          NaN
# 1  2018        Russia     32   France      Croatia
# 2  2014        Brazil     32  Germany    Argentina
# 3  2010  South Africa     32    Spain  Netherlands
# 4  2006       Germany     32    Italy       France
#
#                               TopScorrer  Attendance  AttendanceAvg  Matches
# 0                                    NaN           0              0        0
# 1                         Harry Kane - 6     3031768          47371       64
# 2                    James Rodríguez - 6     3429873          53592       64
# 3  Wesley Sneijder, Thomas Müller... - 5     3178856          49670       64
# 4                     Miroslav Klose - 5     3352605          52384       64

# %%
sns.relplot(x='Host', y='Champion', data=data)

# %%
sns.relplot(x='Host', y='Runner-Up', data=data)

# %%
sns.relplot(x='Year', y='Champion', data=data)

# %%
sns.relplot(x='Attendance', y='Year', data=data)

# %%
sns.relplot(x='Champion', y='Runner-Up', data=data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           22 non-null     int64
#  1   Host           22 non-null     object
#  2   Teams          22 non-null     int64
#  3   Champion       21 non-null     object
#  4   Runner-Up      21 non-null     object
#  5   TopScorrer     21 non-null     object
#  6   Attendance     22 non-null     int64
#  7   AttendanceAvg  22 non-null     int64
#  8   Matches        22 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.7+ KB

# %%
a=data['Champion']
b=data['Runner-Up']
c=data['Host']
d=data['Attendance']

# %%
sns.pairplot(data)

# %%
sns.set()
sns.scatterplot(data['Champion'],data['Year'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Champion', ylabel='Year'>

# %%
sns.set()
sns.scatterplot(data['Champion'],data['Host'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Champion', ylabel='Host'>

# %%
sns.set()
sns.scatterplot(data['Runner-Up'],data['Champion'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Runner-Up', ylabel='Champion'>

# %%
sns.relplot(x='Champion', y='Host', hue='Runner-Up', size='Year',data=data)
